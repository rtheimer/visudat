# %%
from pd_data_converter import *
x = PowerDog("pd_data/powerdog/upload/", "PD612-00010")
bus_configured, ftp, wechselrichter, modulfeld = x.filter_conf()

# %%
print(wechselrichter["Parameter"])
# Out:
# 53        Inverter_B1_A10_AddressAddition
# 54               Inverter_B1_A10_Capacity
# 55             Inverter_B1_A10_Configured
# 56         Inverter_B1_A10_Inverter_Power
# 57             Inverter_B1_A10_Manufactor
#                       ...
# 263    Inverter_Inverter_B1_A5_Modulfield
# 264    Inverter_Inverter_B1_A6_Modulfield
# 265    Inverter_Inverter_B1_A7_Modulfield
# 266    Inverter_Inverter_B1_A8_Modulfield
# 267    Inverter_Inverter_B1_A9_Modulfield
# Name: Parameter, Length: 215, dtype: object
